# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('P4-Movie-Ratings.csv')

# %%
len(data)
# Out:
# 559

# %%
data.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
data.columns=['Film','Genre','CriticRatings','AudienceRatings','BudgetMillions','Year']

# %%
data.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
data['Film']
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
# convert variables to categories 
data.Film.astype('category')
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
data.Film = data.Film.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
data.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
data
# Out:
#                                    Film      Genre  CriticRatings  \
# 0                 (500) Days of Summer      Comedy             87
# 1                           10,000 B.C.  Adventure              9
# 2                            12 Rounds      Action             30
# 3                             127 Hours  Adventure             93
# 4                             17 Again      Comedy             55
# 5                                  2012     Action             39
# 6                            27 Dresses     Comedy             40
# 7                      30 Days of Night     Horror             50
# 8                    30 Minutes or Less     Comedy             43
# 9                                 50/50     Comedy             93
# 10                           88 Minutes      Drama              5
# 11                   A Dangerous Method      Drama             79
# 12            A Nightmare on Elm Street     Horror             13
# ...

# %%
data.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
data.Genre = data.Genre.astype('category')
data.Year = data.Year.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
data.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %%
#get unique genres
data.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
#get unique genres
data.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
j=sns.jointplot(data=data,x='CriticRatings',y='AudienceRatings',kind='hex')

# %%
sns.distplot(data.AudienceRatings,bins=10)
plt.show()

# %%
sns.distplot(data.CriticRatings,bins=20)

# %%
plt.hist(data.AudienceRatings,bins=15)
# Out:
# (array([ 2.,  0.,  1.,  5., 20., 42., 48., 81., 76., 65., 67., 60., 45.,
#         35., 12.]),
#  array([ 0. ,  6.4, 12.8, 19.2, 25.6, 32. , 38.4, 44.8, 51.2, 57.6, 64. ,
#         70.4, 76.8, 83.2, 89.6, 96. ]),
#  <a list of 15 Patch objects>)

# %%
sns.set_style('darkgrid')
j=sns.distplot(data.CriticRatings,bins=15)

# %%
#stacked distribution charts
data[(data.BudgetMillions > 150) & (data.AudienceRatings>60)]
# Out:
#                                                   Film      Genre  \
# 5                                                 2012     Action
# 19                                 Alice in Wonderland  Adventure
# 33                                             Avatar      Action
# 142                       G.I. Joe: The Rise of Cobra      Action
# 167            Harry Potter and the Half-Blood Prince   Adventure
# 190                                          Inception     Action
# 196                                           Iron Man     Action
# 197                                         Iron Man 2     Action
# 303        Pirates of the Caribbean: On Stranger Tides     Action
# 304           Pirates of the Caribbean: At World's End     Action
# 310                Prince of Persia: The Sands of Time     Action
# 314                                  Quantum of Solace     Action
# 383                              Terminator Salvation      Action
# ...

# %%
plt.hist([data.AudienceRatings,data.CriticRatings],stacked=True,bins=15)

plt.show()

# %%
# KDE plot 
sns.kdeplot(data.CriticRatings,data.AudienceRatings,\
          cmap='Reds')

# %%
sns.kdeplot(data.BudgetMillions,data.AudienceRatings)

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
sns.kdeplot(data.BudgetMillions,data.AudienceRatings,ax=axes[0])
sns.kdeplot(data.BudgetMillions,data.CriticRatings,ax=axes[1])

sns.set_style('dark')
plt.show()

# %%
# violin plots 
z=sns.violinplot(data=data,x='Genre',y='CriticRatings')

# %%
z=sns.boxplot(data=data,x='Genre',y='CriticRatings')
